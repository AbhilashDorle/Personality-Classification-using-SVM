# %%
import numpy as np
import cv2
from numpy import single

training_set = []
training_labels = []
#labelling of data
for i in range(1, 40):
    path = 'C://ComputerVision//Project//celebs3_squared//heart//heart (' + str(i) + ').jpg'
    img = cv2.imread(path)
    res = cv2.resize(img, (200, 200))
    gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
    xarr = np.squeeze(np.array(gray_image).astype(np.float32))
    m, v = cv2.PCACompute(xarr, mean=None)
    arr = np.array(v)
    flat_arr = arr.ravel()
    training_set.append(flat_arr)
    training_labels.append(1)
for i in range(1, 10):
    path = 'C:\ComputerVision\Project\celebs3_squared\oblong\oblong (' + str(i) + ').jpg'
    img = cv2.imread(path)
    res = cv2.resize(img, (200, 200))
    gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
    xarr = np.squeeze(np.array(gray_image).astype(np.float32))
    m, v = cv2.PCACompute(xarr, mean=None)
    arr = np.array(v)
    flat_arr = arr.ravel()
    training_set.append(flat_arr)
    training_labels.append(2)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\oval\oval (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(2)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\round\ (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(2)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\square\square (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(2)

#training begins here
trainData = np.array(training_set, np.float32)
responses = np.array(training_labels, np.int32)
svm = cv2.ml.SVM_create()
svm.setType(cv2.ml.SVM_C_SVC)
svm.setKernel(cv2.ml.SVM_LINEAR)
svm.setTermCriteria((cv2.TERM_CRITERIA_COUNT, 100, 1.e-06))
svm.train(trainData, cv2.ml.ROW_SAMPLE, responses)

path1 = 'C:\ComputerVision\Project\celebs3_squared\heart\heart (3).jpg'
im = (cv2.imread('C:\ComputerVision\Project\celebs3_squared\heart\heart (3).jpg',0))
r = cv2.resize(im, (200,200))
im1 = np.float32(r)

#predict statement
print(svm.predict(np.ravel(im1)[None, :]))
for i in range(1, 40):
    path = 'C://ComputerVision//Project//celebs3_squared//oblong//oblong (' + str(i) + ').jpg'
    img = cv2.imread(path)
    res = cv2.resize(img, (200, 200))
    gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
    xarr = np.squeeze(np.array(gray_image).astype(np.float32))
    m, v = cv2.PCACompute(xarr, mean=None)
    arr = np.array(v)
    flat_arr = arr.ravel()
    training_set.append(flat_arr)
    training_labels.append(3)
for i in range(1, 10):
    path = 'C:\ComputerVision\Project\celebs3_squared\heart\heart (' + str(i) + ').jpg'
    img = cv2.imread(path)
    res = cv2.resize(img, (200, 200))
    gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
    xarr = np.squeeze(np.array(gray_image).astype(np.float32))
    m, v = cv2.PCACompute(xarr, mean=None)
    arr = np.array(v)
    flat_arr = arr.ravel()
    training_set.append(flat_arr)
    training_labels.append(4)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\oval\oval (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(4)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\round\round (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(4)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\square\square (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(4)

trainData = np.array(training_set, np.float32)
responses = np.array(training_labels, np.int32)
svm = cv2.ml.SVM_create()
svm.setType(cv2.ml.SVM_C_SVC)
svm.setKernel(cv2.ml.SVM_LINEAR)
svm.setTermCriteria((cv2.TERM_CRITERIA_COUNT, 100, 1.e-06))
svm.train(trainData, cv2.ml.ROW_SAMPLE, responses)
im = (cv2.imread('C:\ComputerVision\Project\celebs3_squared\heart\heart (3).jpg',0))
r = cv2.resize(im, (200,200))
im1 = np.float32(r)
print(svm.predict(np.ravel(im1)[None, :]))

for i in range(1, 40):
    path = 'C://ComputerVision//Project//celebs3_squared//oval//oval (' + str(i) + ').jpg'
    img = cv2.imread(path)
    res = cv2.resize(img, (200, 200))
    gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
    xarr = np.squeeze(np.array(gray_image).astype(np.float32))
    m, v = cv2.PCACompute(xarr, mean=None)
    arr = np.array(v)
    flat_arr = arr.ravel()
    training_set.append(flat_arr)
    training_labels.append(5)
for i in range(1, 10):
    path = 'C:\ComputerVision\Project\celebs3_squared\heart\heart (' + str(i) + ').jpg'
    img = cv2.imread(path)
    res = cv2.resize(img, (200, 200))
    gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
    xarr = np.squeeze(np.array(gray_image).astype(np.float32))
    m, v = cv2.PCACompute(xarr, mean=None)
    arr = np.array(v)
    flat_arr = arr.ravel()
    training_set.append(flat_arr)
    training_labels.append(6)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\oblong\oblong (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(6)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\round\round (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(6)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\square\square (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(6)

trainData = np.array(training_set, np.float32)
responses = np.array(training_labels, np.int32)
svm = cv2.ml.SVM_create()
svm.setType(cv2.ml.SVM_C_SVC)
svm.setKernel(cv2.ml.SVM_LINEAR)
svm.setTermCriteria((cv2.TERM_CRITERIA_COUNT, 100, 1.e-06))
svm.train(trainData, cv2.ml.ROW_SAMPLE, responses)

im = (cv2.imread('C:\ComputerVision\Project\celebs3_squared\oval\oval (3).jpg',0))
r = cv2.resize(im, (200,200))
im1 = np.float32(r)
print(svm.predict(np.ravel(im1)[None, :]))

for i in range(1, 40):
    path = 'C://ComputerVision//Project//celebs3_squared//round//round (' + str(i) + ').jpg'
    img = cv2.imread(path)
    res = cv2.resize(img, (200, 200))
    gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
    xarr = np.squeeze(np.array(gray_image).astype(np.float32))
    m, v = cv2.PCACompute(xarr, mean=None)
    arr = np.array(v)
    flat_arr = arr.ravel()
    training_set.append(flat_arr)
    training_labels.append(7)
for i in range(1, 10):
    path = 'C:\ComputerVision\Project\celebs3_squared\heart\heart (' + str(i) + ').jpg'
    img = cv2.imread(path)
    res = cv2.resize(img, (200, 200))
    gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
    xarr = np.squeeze(np.array(gray_image).astype(np.float32))
    m, v = cv2.PCACompute(xarr, mean=None)
    arr = np.array(v)
    flat_arr = arr.ravel()
    training_set.append(flat_arr)
    training_labels.append(8)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\oblong\oblong (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(8)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\oval\oval (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(8)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\square\square (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(8)

trainData = np.array(training_set, np.float32)
responses = np.array(training_labels, np.int32)
svm = cv2.ml.SVM_create()
svm.setType(cv2.ml.SVM_C_SVC)
svm.setKernel(cv2.ml.SVM_LINEAR)
svm.setTermCriteria((cv2.TERM_CRITERIA_COUNT, 100, 1.e-06))
svm.train(trainData, cv2.ml.ROW_SAMPLE, responses)

im = (cv2.imread('C:\ComputerVision\Project\celebs3_squared\round\round (3).jpg',0))
r = cv2.resize(im, (200,200))
im1 = np.float32(r)
print(svm.predict(np.ravel(im1)[None, :]))

for i in range(1, 40):
    path = 'C://ComputerVision//Project//celebs3_squared//square//square (' + str(i) + ').jpg'
    img = cv2.imread(path)
    res = cv2.resize(img, (200, 200))
    gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
    xarr = np.squeeze(np.array(gray_image).astype(np.float32))
    m, v = cv2.PCACompute(xarr, mean=None)
    arr = np.array(v)
    flat_arr = arr.ravel()
    training_set.append(flat_arr)
    training_labels.append(9)
for i in range(1, 10):
    path = 'C:\ComputerVision\Project\celebs3_squared\heart\heart (' + str(i) + ').jpg'
    img = cv2.imread(path)
    res = cv2.resize(img, (200, 200))
    gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
    xarr = np.squeeze(np.array(gray_image).astype(np.float32))
    m, v = cv2.PCACompute(xarr, mean=None)
    arr = np.array(v)
    flat_arr = arr.ravel()
    training_set.append(flat_arr)
    training_labels.append(10)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\oblong\oblong (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(10)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\oval\oval (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(10)
for i in range(1, 10):
        path = 'C:\ComputerVision\Project\celebs3_squared\round\round (' + str(i) + ').jpg'
        img = cv2.imread(path)
        res = cv2.resize(img, (200, 200))
        gray_image = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
        xarr = np.squeeze(np.array(gray_image).astype(np.float32))
        m, v = cv2.PCACompute(xarr, mean=None)
        arr = np.array(v)
        flat_arr = arr.ravel()
        training_set.append(flat_arr)
        training_labels.append(10)
trainData = np.array(training_set, np.float32)
responses = np.array(training_labels, np.int32)
svm = cv2.ml.SVM_create()
svm.setType(cv2.ml.SVM_C_SVC)
svm.setKernel(cv2.ml.SVM_LINEAR)
svm.setTermCriteria((cv2.TERM_CRITERIA_COUNT, 100, 1.e-06))
svm.train(trainData, cv2.ml.ROW_SAMPLE, responses)
im = (cv2.imread('C:\ComputerVision\Project\celebs3_squared\square\square (3).jpg',0))
r = cv2.resize(im, (200,200))
im1 = np.float32(r)
print(svm.predict(np.ravel(im1)[None, :]))
